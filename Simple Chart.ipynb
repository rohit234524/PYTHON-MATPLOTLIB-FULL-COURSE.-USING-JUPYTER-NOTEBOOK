# %%
import matplotlib.pyplot as plt
x=["1","2","3","4"]
y=["2","4","6","8"]

c=("r","b","y","g")
# plt.plot(x,y,color=c) #LIne Chart Create
plt.bar(x,y,color=c) #Bar Chart Create
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>
