# %% [markdown]
# # Stack Plot(Area plot).

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
# area=[1,2,3,4,5]
area1=[1,3,2,5,4]
area2=[1,2,3,4,5]
area3=[1,2,3,4,5]

l=["area1","area2","area3"]

plt.stackplot(x,area,area1,area2,labels=l,colors=["r","g","m"],baseline="zero")# baseine=sym,zero,wiggle;
# Baseline=zero(Basic Stack Plot)

plt.title("Pyhon.")
plt.xlabel("x-axis")
plt.legend()
plt.show()
