# %% [markdown]
# # Histogram Plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))#10 to 60 (fifty(50)value show)
print(x)
# Out:
# [27 51 28 16 52 52 36 53 48 31 28 31 44 14 16 35 53 32 53 55 46 10 38 59
#  38 46 44 32 47 42 33 53 27 28 57 31 43 44 41 29 17 19 24 47 23 23 20 57
#  46 41]

# %%
no=[27,51,28,16,52 ,52 ,36, 53, 48, 31, 28 ,31 ,44 ,14 ,16 ,3,5, 5,3, 32, 53 ,55 ,46, 11, 38, 59,
 38, 46, 44, 32, 47, 42, 33, 53 ,27 ,28, 57, 31, 43, 44 ,41, 29, 17, 19, 24, 47 ,23 ,23, 20, 57,
 46 ,41]
l=[10,20,30,40,50,60]

plt.title("Wscube.",fontsize=20)
plt.xlabel("R language.")
plt.ylabel("Number")


#plt.hist(no,color="b",edgecolor="r",bins=l)
#plt.hist(no,"auto",(0,150),edgecolor="y")
#plt.hist(no,color="b",edgecolor="r",cumulative=-1)#Cumulative Parameter=Frequency bargraph reverse. 

#plt.hist(no,color="b",edgecolor="r",cumulative=-1,bottom=500)#Bottom parameter=Bottom number range start.
#plt.hist(no,color="b",edgecolor="r",align="mid",histtype="step")
#plt.hist(no,color="b",edgecolor="r",align="mid",histtype="stepfilled")

#plt.hist(no,color="b",edgecolor="r",align="mid",histtype="bar")
#plt.hist(no,color="b",edgecolor="r",align="mid",histtype="barstacked",rwidth=0.8,log=True)#histype=Histogram type change.
#plt.hist(no,color="b",edgecolor="r",align="mid",histtype="barstacked",orientation="horizontal",rwidth=0.8)

plt.hist(no,color="b",edgecolor="r",align="mid",label="Python")
plt.axvline(40,color="r",label="Axvline")#Axvline through realize workig or non-working data.
plt.grid()
plt.legend()
plt.show()
