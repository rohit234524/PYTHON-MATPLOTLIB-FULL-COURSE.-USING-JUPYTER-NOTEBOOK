# %% [markdown]
# # Savefig.

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,4,3,6,4]

plt.plot(x,y,color="r")

# plt.savefig("line")
#plt.savefig("Line1",dpi=200,facecolor="g")#dpi(dot per inch).and facecolor(face color Change.)
#plt.savefig("C:\\Users\\Rohit\\hello\\Include\\Line12.pdf",facecolor="g")# Pdf Save File.
# plt.savefig("C:\\Users\\Rohit\\hello\\Include\\Line12.jpeg",facecolor="g")
plt.savefig("C:\\Users\\Rohit\\hello\\Include\\Line14.png",facecolor="g",dpi=100,transparent=True,bbox_inches="tight")

plt.show()
